# %% [markdown]
# <a href="https://colab.research.google.com/github/krisnasetyadi/texting/blob/master/lemma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

# %%
from urllib.request import urlopen
url = "https://www.gutenberg.org/cache/epub/66249/pg66249.txt"
raw = urlopen(url).read().decode('utf-8')
type(raw)
# Out:
# str

# %%
len(raw)
# Out:
# 209305

# %%
# baca 100 buah string pertama
raw[:100]
# Out:
# '\ufeffThe Project Gutenberg eBook of The Hunter Hercules, or The Champion Rider\r\nof the Plains, by Harry '

# %%
# untuk dapat menggunakan tokenizer dari library nltk kita harus download tokenizernya dulu 
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
tokens = nltk.word_tokenize(raw)
type(tokens)
# Out:
# list

# %%
# periksa isi list
len(tokens)
# Out:
# 42289

# %%
# liat 10 buah token pertama
tokens[:10]
# Out:
# ['\ufeffThe',
#  'Project',
#  'Gutenberg',
#  'eBook',
#  'of',
#  'The',
#  'Hunter',
#  'Hercules',
#  ',',
#  'or']

# %%
# lowecase semua, masukin ke dalam list, untuk semua x yg ada di variable token
token_lower = [x.lower() for x in tokens]
print(token_lower)
# Out:
# ['\ufeffthe', 'project', 'gutenberg', 'ebook', 'of', 'the', 'hunter', 'hercules', ',', 'or', 'the', 'champion', 'rider', 'of', 'the', 'plains', ',', 'by', 'harry', 'st.', 'george', 'this', 'ebook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'in', 'the', 'united', 'states', 'and', 'most', 'other', 'parts', 'of', 'the', 'world', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions', 'whatsoever', '.', 'you', 'may', 'copy', 'it', ',', 'give', 'it', 'away', 'or', 're-use', 'it', 'under', 'the', 'terms', 'of', 'the', 'project', 'gutenberg', 'license', 'included', 'with', 'this', 'ebook', 'or', 'online', 'at', 'www.gutenberg.org', '.', 'if', 'you', 'are', 'not', 'located', 'in', 'the', 'united', 'states', ',', 'you', 'will', 'have', 'to', 'check', 'the', 'laws', 'of', 'the', 'country', 'where', 'you', 'are', 'located', 'before', 'using', 'this', 'ebook', '.', 'title', ':', 'the', 'hunter', 'hercules', ',', 'or', 'the', 'champion', 'rider', 'of', 'the', 'plains', 'be
# ...

# %%
# kita mau cari stemmnya
porter = nltk.PorterStemmer()
[porter.stem(t) for t in tokens]
# Out:
# ['\ufeffthe',
#  'project',
#  'gutenberg',
#  'ebook',
#  'of',
#  'the',
#  'hunter',
#  'hercul',
#  ',',
#  'or',
#  'the',
#  'champion',
#  'rider',
#  'of',
#  'the',
#  'plain',
#  ',',
#  'by',
#  'harri',
#  'st.',
#  'georg',
#  'thi',
#  'ebook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyon',
#  'anywher',
#  'in',
#  'the',
#  'unit',
#  'state',
#  'and',
#  'most',
#  'other',
#  'part',
#  'of',
#  'the',
#  'world',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrict',
#  'whatsoev',
#  '.',
#  'you',
#  'may',
#  'copi',
#  'it',
#  ',',
#  'give',
#  'it',
#  'away',
#  'or',
#  're-us',
#  'it',
#  'under',
#  'the',
#  'term',
#  'of',
#  'the',
#  'project',
#  'gutenberg',
#  'licens',
#  'includ',
#  'with',
#  'thi',
#  'ebook',
#  'or',
#  'onlin',
#  'at',
#  'www.gutenberg.org',
#  '.',
#  'If',
#  'you',
#  'are',
#  'not',
#  'locat',
#  'in',
#  'the',
#  'unit',
#  'state',
#  ',',
#  'you',
#  'will',
# ...

# %%
# lancaster stemmer
lancaster = nltk.LancasterStemmer()
[lancaster.stem(t) for t in tokens]
# Out:
# ['\ufeffthe',
#  'project',
#  'gutenberg',
#  'ebook',
#  'of',
#  'the',
#  'hunt',
#  'herc',
#  ',',
#  'or',
#  'the',
#  'champ',
#  'rid',
#  'of',
#  'the',
#  'plain',
#  ',',
#  'by',
#  'harry',
#  'st.',
#  'georg',
#  'thi',
#  'ebook',
#  'is',
#  'for',
#  'the',
#  'us',
#  'of',
#  'anyon',
#  'anywh',
#  'in',
#  'the',
#  'unit',
#  'stat',
#  'and',
#  'most',
#  'oth',
#  'part',
#  'of',
#  'the',
#  'world',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrict',
#  'whatsoev',
#  '.',
#  'you',
#  'may',
#  'cop',
#  'it',
#  ',',
#  'giv',
#  'it',
#  'away',
#  'or',
#  're-us',
#  'it',
#  'und',
#  'the',
#  'term',
#  'of',
#  'the',
#  'project',
#  'gutenberg',
#  'licens',
#  'includ',
#  'with',
#  'thi',
#  'ebook',
#  'or',
#  'onlin',
#  'at',
#  'www.gutenberg.org',
#  '.',
#  'if',
#  'you',
#  'ar',
#  'not',
#  'loc',
#  'in',
#  'the',
#  'unit',
#  'stat',
#  ',',
#  'you',
#  'wil',
#  'hav',
#  'to',
# ...

# %%
# mengunduh lemmatizer wordnet
nltk.download('wordnet')
# database kata kata dalam bahasa inggris. 
wnl = nltk.WordNetLemmatizer()
[wnl.lemmatize(t) for t in tokens]
# lemma yang ada di variabel token token
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# ['\ufeffThe',
#  'Project',
#  'Gutenberg',
#  'eBook',
#  'of',
#  'The',
#  'Hunter',
#  'Hercules',
#  ',',
#  'or',
#  'The',
#  'Champion',
#  'Rider',
#  'of',
#  'the',
#  'Plains',
#  ',',
#  'by',
#  'Harry',
#  'St.',
#  'George',
#  'This',
#  'eBook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'in',
#  'the',
#  'United',
#  'States',
#  'and',
#  'most',
#  'other',
#  'part',
#  'of',
#  'the',
#  'world',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restriction',
#  'whatsoever',
#  '.',
#  'You',
#  'may',
#  'copy',
#  'it',
#  ',',
#  'give',
#  'it',
#  'away',
#  'or',
#  're-use',
#  'it',
#  'under',
#  'the',
#  'term',
#  'of',
#  'the',
#  'Project',
#  'Gutenberg',
#  'License',
#  'included',
#  'with',
#  'this',
#  'eBook',
#  'or',
#  'online',
#  'at',
#  'www.gutenberg.org',
# ...
